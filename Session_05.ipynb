# %% [markdown]
# # Python Assignment 1
# ## Session 5 👾

# %% [markdown]
# # Question 1

# %% [markdown]
# ![Screenshot 2026-09-15 at 6.23.26 AM.png](<attachment:Screenshot 2026-09-15 at 6.23.26 AM.png>)

# %%
product = {'id': 101, 'name': 'Notebook', 'price': 125.0}

product_id = product['id']
product_name = product['name']
product_price = product['price']

print("Inital Product:", product)
print("Product Id:", product_id)
print("Prouduct Name:", product_name)
print("Product Price:", product_price)



product = {'id': 202, 'name': 'Marker', 'price': 45.0}

product_id = product['id']
product_name = product['name']
product_price = product['price']

print("Inital Product:", product)
print("Product Id:", product_id)
print("Prouduct Name:", product_name)
print("Product Price:", product_price)
# Out:
# Inital Product: {'id': 101, 'name': 'Notebook', 'price': 125.0}
# Product Id: 101
# Prouduct Name: Notebook
# Product Price: 125.0
# Inital Product: {'id': 202, 'name': 'Marker', 'price': 45.0}
# Product Id: 202
# Prouduct Name: Marker
# Product Price: 45.0

# %% [markdown]
# # Question 2

# %% [markdown]
# ![Screenshot 2026-09-15 at 6.23.48 AM.png](<attachment:Screenshot 2026-09-15 at 6.23.48 AM.png>)

# %%
product = {'name':'pen', 'price':20.0}
stock = 50
revised_price = 22.0

print("Before:", product)

product['stock'] = stock
product['price'] = revised_price


print("Stock value:", 50)
print("Revised price:", 22.0)
print("After:", product)


product = {'name':'pen', 'price':20.0}
stock = 0
revised_price = 20.0

print("Before:", product)

product['stock'] = stock
product['price'] = revised_price


print("Stock value:", 0)
print("Revised price:", 22.0)
print("After:", product)
# Out:
# Before: {'name': 'pen', 'price': 20.0}
# Stock value: 50
# Revised price: 22.0
# After: {'name': 'pen', 'price': 22.0, 'stock': 50}
# Before: {'name': 'pen', 'price': 20.0}
# Stock value: 0
# Revised price: 22.0
# After: {'name': 'pen', 'price': 20.0, 'stock': 0}

# %% [markdown]
# # Question 3

# %% [markdown]
# ![Screenshot 2026-09-15 at 6.24.05 AM.png](<attachment:Screenshot 2026-09-15 at 6.24.05 AM.png>)

# %%
employee = {'id': 'E101', 'name':'Ravi'}
request_key = 'department'

print("Before:", employee)
print("Requested Key:", request_key)

result = employee.get(request_key, 'Not available')

print("After get():", result)
print("Final result:", result)

employee = {'id': 'E101', 'name':'Ravi', 'department': 'Finance'}
request_key = 'department'

print("Before:", employee)
print("Requested Key:", request_key)

result = employee.get(request_key, 'Not available')

print("After get():", result)
print("Final result:", result)
# Out:
# Before: {'id': 'E101', 'name': 'Ravi'}
# Requested Key: department
# After get(): Not available
# Final result: Not available
# Before: {'id': 'E101', 'name': 'Ravi', 'department': 'Finance'}
# Requested Key: department
# After get(): Finance
# Final result: Finance

# %% [markdown]
# # Question 4

# %% [markdown]
# ![Screenshot 2026-09-15 at 6.24.19 AM.png](<attachment:Screenshot 2026-09-15 at 6.24.19 AM.png>)

# %%
cart = {'Pen':3, 'Notebook':2, 'Marker':1}
item_to_remove = 'Marker'

print("Before:", cart)
print("Item to remove:", item_to_remove)

removed_quantity = cart.pop(item_to_remove)

print("Removed Quantity:",removed_quantity)
print("Remaining Cart:", cart)



cart = {'Pen':3, 'Notebook':2}
item_to_remove = 'Pen'

print("Before:", cart)
print("Item to remove:", item_to_remove)

removed_quantity = cart.pop(item_to_remove)

print("Removed Quantity:",removed_quantity)
print("Remaining Cart:", cart)
# Out:
# Before: {'Pen': 3, 'Notebook': 2, 'Marker': 1}
# Item to remove: Marker
# Removed Quantity: 1
# Remaining Cart: {'Pen': 3, 'Notebook': 2}
# Before: {'Pen': 3, 'Notebook': 2}
# Item to remove: Pen
# Removed Quantity: 3
# Remaining Cart: {'Notebook': 2}

# %% [markdown]
# # Question 5

# %% [markdown]
# ![Screenshot 2026-09-15 at 6.24.34 AM.png](<attachment:Screenshot 2026-09-15 at 6.24.34 AM.png>)

# %%
student = {'name': 'Asha', 'marks': {'Python':82, 'Statistics':76}}

print("Initial student:", student)
marks = student['marks']
print("selecetd marks dictionary:", marks)
python_marks = student['marks']['Python']
statistics_marks = student['marks']['Statistics']

print("Python Marks:", python_marks)
print("Statistics Marks:", statistics_marks)


student = {'name': 'Asha', 'marks': {'Python':0, 'Statistics':100}}

print("Initial student:", student)
marks = student['marks']
print("selecetd marks dictionary:", marks)
python_marks = student['marks']['Python']
statistics_marks = student['marks']['Statistics']

print("Python Marks:", python_marks)
print("Statistics Marks:", statistics_marks)
# Out:
# Initial student: {'name': 'Asha', 'marks': {'Python': 82, 'Statistics': 76}}
# selecetd marks dictionary: {'Python': 82, 'Statistics': 76}
# Python Marks: 82
# Statistics Marks: 76
# Initial student: {'name': 'Asha', 'marks': {'Python': 0, 'Statistics': 100}}
# selecetd marks dictionary: {'Python': 0, 'Statistics': 100}
# Python Marks: 0
# Statistics Marks: 100

# %% [markdown]
# # Question 6

# %% [markdown]
# ![Screenshot 2026-09-15 at 6.24.49 AM.png](<attachment:Screenshot 2026-09-15 at 6.24.49 AM.png>)

# %%
defaults = {'theme': 'light', 'page_size': 20}
user = {'theme': 'dark'}

print("Defaults:", defaults)
print("User:", user)

settings = defaults | user
print("Merged settings:", settings)


defaults = {'theme': 'light', 'page_size': 20}
user = {'page_size': 50}

print("Defaults:", defaults)
print("User:", user)

settings = defaults | user
print("Merged settings:", settings)
# Out:
# Defaults: {'theme': 'light', 'page_size': 20}
# User: {'theme': 'dark'}
# Merged settings: {'theme': 'dark', 'page_size': 20}
# Defaults: {'theme': 'light', 'page_size': 20}
# User: {'page_size': 50}
# Merged settings: {'theme': 'light', 'page_size': 50}

# %% [markdown]
# # Question 7

# %% [markdown]
# ![Screenshot 2026-09-15 at 6.25.09 AM.png](<attachment:Screenshot 2026-09-15 at 6.25.09 AM.png>)

# %%
inventory = {'Pen':40, 'Notebook':25, 'Marker':18 }

print("Starting inventory:", inventory)
keys_view  = inventory.keys()
values_view = inventory.values()
items_view = inventory.items()

print("Key_view", keys_view)
print("values_view", values_view)
print("items_view", items_view)


inventory = {}
print("Starting inventory:", inventory)
keys_view  = inventory.keys()
values_view = inventory.values()
items_view = inventory.items()

print("Key_view", keys_view)
print("values_view", values_view)
print("items_view", items_view)
# Out:
# Starting inventory: {'Pen': 40, 'Notebook': 25, 'Marker': 18}
# Key_view dict_keys(['Pen', 'Notebook', 'Marker'])
# values_view dict_values([40, 25, 18])
# items_view dict_items([('Pen', 40), ('Notebook', 25), ('Marker', 18)])
# Starting inventory: {}
# Key_view dict_keys([])
# values_view dict_values([])
# items_view dict_items([])

# %% [markdown]
# # Question 8

# %% [markdown]
# ![Screenshot 2026-09-15 at 6.25.37 AM.png](<attachment:Screenshot 2026-09-15 at 6.25.37 AM.png>)

# %%
original = {'theme': 'light', 'page_size': 20}

print("Original", original)

alias = original
copied = original.copy()

print("Alias after assignment:", alias)
print("Copy after copy():", copied)

original['theme'] = 'dark'


print("Original after update:", original)
print("alias after original update:",alias)
print("copied after original update:", copied)

 # 2nd Run
original = {}

print("Original", original)

alias = original
copied = original.copy()

print("Alias after assignment:", alias)
print("Copy after copy():", copied)

original['theme'] = 'dark'


print("Original after update:", original)
print("alias after original update:",alias)
print("copied after original update:", copied)
# Out:
# Original {'theme': 'light', 'page_size': 20}
# Alias after assignment: {'theme': 'light', 'page_size': 20}
# Copy after copy(): {'theme': 'light', 'page_size': 20}
# Original after update: {'theme': 'dark', 'page_size': 20}
# alias after original update: {'theme': 'dark', 'page_size': 20}
# copied after original update: {'theme': 'light', 'page_size': 20}
# Original {}
# Alias after assignment: {}
# Copy after copy(): {}
# Original after update: {'theme': 'dark'}
# alias after original update: {'theme': 'dark'}
# copied after original update: {}
