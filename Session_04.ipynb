# %% [markdown]
# # Python Assignment 1
# ## Session 4 🥷🏻

# %% [markdown]
# # Question 1

# %% [markdown]
# ![Screenshot 2026-09-15 at 6.16.13 AM.png](<attachment:Screenshot 2026-09-15 at 6.16.13 AM.png>)

# %%
products = ['Pen', 'Notebook', 'Marker', 'Folder', 'Stapler']
print("Initial Products:", products)

first_product = products[0]
last_product = products[-1]
middle_products = products[1:4]
reversesd_products = products[::-1]

print("Product[0]:",first_product)
print('Product[-1]:',last_product)
print("Product[1:4]:", middle_products)
print("products[::-1]:", reversesd_products)


products = ['Only item']
print("Initial Products:", products)

first_product = products[0]
last_product = products[-1]
middle_products = products[1:4]
reversesd_products = products[::-1]

print("Product[0]:",first_product)
print('Product[-1]:',last_product)
print("Product[1:4]:", middle_products)
print("products[::-1]:", reversesd_products)
# Out:
# Initial Products: ['Pen', 'Notebook', 'Marker', 'Folder', 'Stapler']
# Product[0]: Pen
# Product[-1]: Stapler
# Product[1:4]: ['Notebook', 'Marker', 'Folder']
# products[::-1]: ['Stapler', 'Folder', 'Marker', 'Notebook', 'Pen']
# Initial Products: ['Only item']
# Product[0]: Only item
# Product[-1]: Only item
# Product[1:4]: []
# products[::-1]: ['Only item']

# %% [markdown]
# # Question 2

# %% [markdown]
# ![Screenshot 2026-09-15 at 6.16.37 AM.png](<attachment:Screenshot 2026-09-15 at 6.16.37 AM.png>)

# %%
items = ['Pen', 'Notebook']
new_items = ['Marker', 'Folder']

print("Inital items:", items)
print("New items:", new_items)

append_result = items.copy()
append_result.append(new_items)

extend_result = items.copy()
extend_result.extend(new_items)

print("After append():", append_result)
print("After extend():", extend_result)


items = []
new_items = ['Marker', 'Folder']

print("Inital items:", items)
print("New items:", new_items)

append_result = items.copy()
append_result.append(new_items)

extend_result = items.copy()
extend_result.extend(new_items)

print("After append():", append_result)
print("After extend():", extend_result)
# Out:
# Inital items: ['Pen', 'Notebook']
# New items: ['Marker', 'Folder']
# After append(): ['Pen', 'Notebook', ['Marker', 'Folder']]
# After extend(): ['Pen', 'Notebook', 'Marker', 'Folder']
# Inital items: []
# New items: ['Marker', 'Folder']
# After append(): [['Marker', 'Folder']]
# After extend(): ['Marker', 'Folder']

# %% [markdown]
# # Question 3

# %% [markdown]
# ![Screenshot 2026-09-15 at 6.16.56 AM.png](<attachment:Screenshot 2026-09-15 at 6.16.56 AM.png>)

# %%
cities = ['Delhi', 'Mumbai', 'Pune', 'Jaipur']
removed_city = 'Pune'
print("Inital cities:", cities)
print("City to remove:", removed_city)

cities.insert(1, 'Chennai')
print("After insert()", cities)

print("Before remove()", cities)
cities.remove(removed_city)
print("After remove()", cities)

final_city = cities.pop()
print("After pop():", cities)
print("Final city stored by pop():", final_city)



cities = ['Delhi', 'Pune']
removed_city = 'Pune'
print("Inital cities:", cities)
print("City to remove:", removed_city)

cities.insert(1, 'Chennai')
print("After insert()", cities)

print("Before remove()", cities)
cities.remove(removed_city)
print("After remove()", cities)

final_city = cities.pop()
print("After pop():", cities)
print("Final city stored by pop():", final_city)
# Out:
# Inital cities: ['Delhi', 'Mumbai', 'Pune', 'Jaipur']
# City to remove: Pune
# After insert() ['Delhi', 'Chennai', 'Mumbai', 'Pune', 'Jaipur']
# Before remove() ['Delhi', 'Chennai', 'Mumbai', 'Pune', 'Jaipur']
# After remove() ['Delhi', 'Chennai', 'Mumbai', 'Jaipur']
# After pop(): ['Delhi', 'Chennai', 'Mumbai']
# Final city stored by pop(): Jaipur
# Inital cities: ['Delhi', 'Pune']
# City to remove: Pune
# After insert() ['Delhi', 'Chennai', 'Pune']
# Before remove() ['Delhi', 'Chennai', 'Pune']
# After remove() ['Delhi', 'Chennai']
# After pop(): ['Delhi']
# Final city stored by pop(): Chennai

# %% [markdown]
# # Question 4

# %% [markdown]
# ![Screenshot 2026-09-15 at 6.17.15 AM.png](<attachment:Screenshot 2026-09-15 at 6.17.15 AM.png>)

# %%
scores = [72 ,91, 68, 85, 77]
sorted_scores = sorted(scores)
print(scores)
print(sorted_scores)


scores.sort(reverse=True)
print(scores)
print(sorted_scores)

scores = [85, 85, 72]
sorted_scores = sorted(scores)
print(scores)
print(sorted_scores)


scores.sort(reverse=True)
print(scores)
print(sorted_scores)
# Out:
# [72, 91, 68, 85, 77]
# [68, 72, 77, 85, 91]
# [91, 85, 77, 72, 68]
# [68, 72, 77, 85, 91]
# [85, 85, 72]
# [72, 85, 85]
# [85, 85, 72]
# [72, 85, 85]

# %% [markdown]
# # Question 5

# %% [markdown]
# ![Screenshot 2026-09-15 at 6.17.29 AM.png](<attachment:Screenshot 2026-09-15 at 6.17.29 AM.png>)

# %%
matrix = [[10,20], [30,40], [50,60]]
print("Initial Matrix:", matrix)

value_10 = matrix[0][0]
value_40 = matrix[1][1]
value_60 = matrix[2][1]

print("Matrix[0][0]-Retrived value", value_10)
print("Matrix[1][1]-Retrived value", value_40)
print("Matrix[2][1]-Retrived value", value_60)

matrix = [[1,2], [3,4], [5,6]]
print("Initial Matrix:", matrix)

value_10 = matrix[0][0]
value_40 = matrix[1][1]
value_60 = matrix[2][1]

print("Matrix[0][0]-Retrived value", value_10)
print("Matrix[1][1]-Retrived value", value_40)
print("Matrix[2][1]-Retrived value", value_60)
# Out:
# Initial Matrix: [[10, 20], [30, 40], [50, 60]]
# Matrix[0][0]-Retrived value 10
# Matrix[1][1]-Retrived value 40
# Matrix[2][1]-Retrived value 60
# Initial Matrix: [[1, 2], [3, 4], [5, 6]]
# Matrix[0][0]-Retrived value 1
# Matrix[1][1]-Retrived value 4
# Matrix[2][1]-Retrived value 6

# %% [markdown]
# # Question 6

# %% [markdown]
# ![Screenshot 2026-09-15 at 6.17.34 AM.png](<attachment:Screenshot 2026-09-15 at 6.17.34 AM.png>)

# %%
original = [10,20,30]
print("Original:", original)

alias = original
print("After alias = original:")
print("Original:", original)
print("alias:",alias)

alias.append(40)
print("After alias.append(40):")
print("original:", original)
print("alias:", alias)


original = []
print("Original:", original)

alias = original
print("After alias = original:")
print("Original:", original)
print("alias:",alias)

alias.append(40)
print("After alias.append(40):")
print("original:", original)
print("alias:", alias)
# Out:
# Original: [10, 20, 30]
# After alias = original:
# Original: [10, 20, 30]
# alias: [10, 20, 30]
# After alias.append(40):
# original: [10, 20, 30, 40]
# alias: [10, 20, 30, 40]
# Original: []
# After alias = original:
# Original: []
# alias: []
# After alias.append(40):
# original: [40]
# alias: [40]

# %% [markdown]
# # Question 7

# %% [markdown]
# ![Screenshot 2026-09-15 at 6.17.54 AM.png](<attachment:Screenshot 2026-09-15 at 6.17.54 AM.png>)

# %%
original = [[1], [2]]
print("Original ", original)

independent = [original[0].copy(), original[1].copy()]
print("After creating independent copy:")
print("Original:", original)
print("Independent:", independent)

original[0].append(3)
print("After original[0].append(3):")
print("Original:", original)
print("Independent:", independent)


original = [[], []]
print("Original ", original)

independent = [original[0].copy(), original[1].copy()]
print("After creating independent copy:")
print("Original:", original)
print("Independent:", independent)

original[0].append(3)
print("After original[0].append(3):")
print("Original:", original)
print("Independent:", independent)
# Out:
# Original  [[1], [2]]
# After creating independent copy:
# Original: [[1], [2]]
# Independent: [[1], [2]]
# After original[0].append(3):
# Original: [[1, 3], [2]]
# Independent: [[1], [2]]
# Original  [[], []]
# After creating independent copy:
# Original: [[], []]
# Independent: [[], []]
# After original[0].append(3):
# Original: [[3], []]
# Independent: [[], []]

# %% [markdown]
# # Question 8

# %% [markdown]
# ![Screenshot 2026-09-15 at 6.18.15 AM.png](<attachment:Screenshot 2026-09-15 at 6.18.15 AM.png>)

# %%
first_list = ['A', 'B']
second_list = ['C', 'D']
repeat_count = 2

print("Starting first list:", first_list)
print("Starting second list:", second_list)
print("Starting repeat count:", repeat_count)

combine = first_list + second_list
print("Combine = first_list + second_list:", combine)

repeated = combine * repeat_count
print("Repeat = combine * repeat count:", repeated)


first_list = ['A']
second_list = []
repeat_count = 0

print("Starting first list:", first_list)
print("Starting second list:", second_list)
print("Starting repeat count:", repeat_count)

combine = first_list + second_list 
print("Combine = first_list + second_list:", combine)

repeated = combine * repeat_count
print("Repeat = combine * repeat count:", repeated)
# Out:
# Starting first list: ['A', 'B']
# Starting second list: ['C', 'D']
# Starting repeat count: 2
# Combine = first_list + second_list: ['A', 'B', 'C', 'D']
# Repeat = combine * repeat count: ['A', 'B', 'C', 'D', 'A', 'B', 'C', 'D']
# Starting first list: ['A']
# Starting second list: []
# Starting repeat count: 0
# Combine = first_list + second_list: ['A']
# Repeat = combine * repeat count: []
